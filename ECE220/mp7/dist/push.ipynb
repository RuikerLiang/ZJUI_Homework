# %%
from base64 import b64encode
import gitlab
import os
import csv

GITLAB_HOST = 'http://10.105.100.202:81'
TOKEN = 'glpat-XymeScjjLULVRWv1yfhh'
all_path = 'C:/ece220_mp1/'

data = {
    'branch': 'main',
    'commit_message': 'mp7 added',
    'actions': [
        # primeNumber
        {
            # Binary files need to be base64 encoded
            'action': 'create',
            'file_path': '/mp7/dist/primeNumber/isPrime.o',
            'content': b64encode(open('primeNumber/isPrime.o', mode='r+b').read()).decode(),
            'encoding': 'base64',
        }
        {
            'action': 'create',
            'file_path': '/mp7/dist/primeNumber/isPrime.h',
            'content': open(('primeNumber/isPrime.h'), 'r', encoding='utf-8').read(),
        }
        {
            'action': 'create',
            'file_path': '/mp7/dist/primeNumber/Makefile',
            'content': open(('primeNumber/Makefile'), 'r', encoding='utf-8').read(),
        }
        {
            'action': 'create',
            'file_path': '/mp7/dist/primeNumber/primeNumber.c',
            'content': open(('primeNumber/primeNumber.c'), 'r', encoding='utf-8').read(),
        }
        # printRev
        {
            'action': 'create',
            'file_path': '/mp7/dist/printRev/Makefile',
            'content': open(('printRev/Makefile'), 'r', encoding='utf-8').read(),
        }
        {
            'action': 'create',
            'file_path': '/mp7/dist/printRev/pr_buggy.c',
            'content': open(('printRev/pr_buggy.c'), 'r', encoding='utf-8').read(),
        }
        {
            'action': 'create',
            'file_path': '/mp7/dist/printRev/prmain.c',
            'content': open(('printRev/prmain.c'), 'r', encoding='utf-8').read(),
        }
        # sort
        {
            'action': 'create',
            'file_path': '/mp7/dist/sort/Makefile',
            'content': open(('sort/Makefile'), 'r', encoding='utf-8').read(),
        }
        {
            'action': 'create',
            'file_path': '/mp7/dist/sort/sort.c',
            'content': open(('sort/sort.c'), 'r', encoding='utf-8').read(),
        }
        {
            'action': 'create',
            'file_path': '/mp7/dist/sort/sort.h',
            'content': open(('sort/sort.h'), 'r', encoding='utf-8').read(),
        }
        {
            # Binary files need to be base64 encoded
            'action': 'create',
            'file_path': '/mp7/dist/sort/sortMain.o',
            'content': b64encode(open('sort/sortMain.o', mode='r+b').read()).decode(),
            'encoding': 'base64',
        }
        {
            'action': 'create',
            'file_path': '/mp7/dist/sort/text1.txt',
            'content': open(('sort/text1.txt'), 'r', encoding='utf-8').read(),
        }

        {
            # Binary files need to be base64 encoded
            'action': 'create',
            'file_path': '/mp7/dist/mp7.pdf',
            'content': b64encode(open('mp7.pdf', mode='r+b').read()).decode(),
            'encoding': 'base64',
        }
        {
            # Binary files need to be base64 encoded
            'action': 'create',
            'file_path': '/mp7/dist/push.ipynb',
            'content': b64encode(open('push.ipynb', mode='r+b').read()).decode(),
            'encoding': 'base64',
        }
        {
            'action': 'create',
            'file_path': '/mp7/dist/report.txt',
            'content': open(('report.txt'), 'r', encoding='utf-8').read(),
        }
        # submission folder
        {
            'action': 'create',
            'file_path': '/mp7/submit/submission_folder',
            'content': open(('submission_folder'), 'r', encoding='utf-8').read(),
        }
    ]
}

with open(os.path.join(all_path, 'rost.txt'), newline = '') as ff:
    reader = csv.reader(ff)
    students = list(reader)
for student in students:
    student_id = student[0]
#student_id = 'tstudent'
    PROJECT_ID = student_id + '/ece220_mps'
    gl = gitlab.Gitlab(GITLAB_HOST, private_token=TOKEN)
    project = gl.projects.get(PROJECT_ID)
    print("try to push", student_id)
    try:
        commit = project.commits.create(data, sudo = student_id)
    except Exception:
        print(student_id + " Failed")
        pass
    
print("")
print("________________end________________")
# Out:
# try to push aren23
# try to push baihaqy23
# try to push abdella23
# try to push ferrell23
# try to push gevorg23
# try to push hayk23
# try to push nico23
# try to push jasmina23
# try to push siuxin23
# try to push terapat23
# try to push zhuohng23
# try to push yuxiang23
# try to push zixuan23
# try to push haotian123
# try to push qiyang23
# try to push beixuan23
# try to push yuxuan123
# try to push runchen23
# try to push yiye23
# try to push yuheng23
# try to push yuyang23
# try to push yanshan23
# try to push enming23
# try to push yuanzhe23
# try to push jingkai23
# try to push haorany21
# try to push liangliang23
# try to push tiancheng23
# try to push siheng23
# try to push di20
# try to push fuyang23
# try to push yuyue23
# try to push zhengyu23
# try to push xiyuan23
# try to push xuzhe23
# try to push wubing23
# try to push yijiang23
# try to push zihan123
# try to push jincheng23
# try to push ran123
# try to push fulin23
# try to push yixing23
# try to push yue23
# ...
